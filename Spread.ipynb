# %%
import pandas as pd
import numpy as np

# %%
data = ([40,100,4000,100000,800,3])
data
# Out:
# [40, 100, 4000, 100000, 800, 3]

# %%
np.mean(data)
# Out:
# np.float64(17490.5)

# %%
np.var(data)
# Out:
# np.float64(1363524344.5833333)

# %%
np.std(data)
# Out:
# np.float64(36925.93051750129)
